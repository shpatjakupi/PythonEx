# %%
import pandas as pd 
import numpy as np
iris_data = pd.read_csv('iris_data.csv')
set(iris_data['Species'])
# Out:
# {'I. setosa', 'I. versicolor', 'I. virginica'}

# %%
from sklearn import preprocessing
# Convert gender to 0 or 1
label_enc =preprocessing.LabelEncoder()
iris_data['Species'] = label_enc.fit_transform(iris_data['Species'].astype(str))
iris_data

# %%
iris_data.plot.scatter(x='Sepal length', y='Sepal width', c='Species', colormap='viridis')

# %%
bw = estimate_bandwidth(iris_data, quantile=0.2)
analyser = MeanShift(bandwidth=bw)
analyser.fit(iris_data)

labels = analyser.labels_
cluster_centers = analyser.cluster_centers_
n_clusters = len(np.unique(labels))
print(labels)
print(cluster_centers)
print(n_clusters)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-638863cc4ae0> in <module>
# ----> 1 bw = estimate_bandwidth(iris_data, quantile=0.2)
#       2 analyser = MeanShift(bandwidth=bw)
#       3 analyser.fit(iris_data)
#       4
#       5 labels = analyser.labels_
#
# NameError: name 'estimate_bandwidth' is not defined

# %%
import matplotlib.pyplot as plt

niris = np.array(iris_data)
plt.scatter(niris[:,0],niris[:,1],c=labels)
plt.scatter(cluster_centers[:,0], cluster_centers[:,1], marker='*', color = 'r', s = 150)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-bdc994111a76> in <module>
#       2
#       3 niris = np.array(iris_data)
# ----> 4 plt.scatter(niris[:,0],niris[:,1],c=labels)
#       5 plt.scatter(cluster_centers[:,0], cluster_centers[:,1], marker='*', color = 'r', s = 150)
#
# NameError: name 'labels' is not defined
